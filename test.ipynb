# %%
import numpy as np

# %%
a,b = 0, 256
batch = np.random.randint(a, b, size=(32, 3, 1080, 1920)) # entre a et b-1
batch.shape
# Out:
# (32, 3, 1080, 1920)

# %%
batch[5, 0].shape
# Out:
# (1080, 1920)

# %%
batch[5,:,0,0]
# Out:
# array([80, 60, 98])

# %%
X = np.array([[1, 2], [3, 4], [5, 6]])
X
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b = np.array([10, 100])
b
# Out:
# array([ 10, 100])

# %%
X + b
# Out:
# array([[ 11, 102],
#        [ 13, 104],
#        [ 15, 106]])
